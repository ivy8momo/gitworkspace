# %%
# 简单样例1
import jieba
from gensim import corpora,models,similarities
import warnings
warnings.filterwarnings(action='ignore',category=UserWarning,module='gensim')

# 语料 all_doc
doc0 = "我不喜欢上海"
doc1 = "上海是一个好地方"
doc2 = "北京是一个好地方"
doc3 = "上海好吃的在哪里"
doc4 = "上海好玩的在哪里"
doc5 = "上海是好地方"
doc6 = "上海路和上海人"
doc7 = "喜欢小吃"
all_doc = []
all_doc.append(doc0)
all_doc.append(doc1)
all_doc.append(doc2)
all_doc.append(doc3)
all_doc.append(doc4)
all_doc.append(doc5)
all_doc.append(doc6)
all_doc.append(doc7)


# 分词
all_doc_list = []
for doc in all_doc:
    doc_list = [word for word in jieba.cut(doc)]
    all_doc_list.append(doc_list)
    
# 获取词袋
dictionary = corpora.Dictionary(all_doc_list) 


# 制作语料库
doc_train_vec = [dictionary.doc2bow(doc) for doc in all_doc_list]
corpus = [dictionary.doc2bow(doc) for doc in all_doc_list]


# 测试
doc_test="我喜欢上海的小吃"
doc_test_list = [word for word in jieba.cut(doc_test)]
doc_test_vec = dictionary.doc2bow(doc_test_list)



# tf-idf
tfidf = models.TfidfModel(doc_train_vec)


index = similarities.SparseMatrixSimilarity(tfidf[doc_train_vec], num_features=len(dictionary.keys()))

sim = index[tfidf[doc_test_vec]]

sorted(enumerate(sim), key=lambda item: -item[1])
# Out:
# D:\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\hey\AppData\Local\Temp\jieba.cache
# Loading model cost 1.395 seconds.
# Prefix dict has been built succesfully.
# [(7, 0.70477605),
#  (0, 0.54680777),
#  (3, 0.17724207),
#  (4, 0.17724207),
#  (5, 0.013545224),
#  (6, 0.01279765),
#  (1, 0.010553493),
#  (2, 0.0)]

# %% [markdown]
# ## 中间结果解析

# %%
# 词袋和字典
print ("##训练文档数目")
print (dictionary.num_docs) #文档数目

print ("##训练集字典，{单词id，对应的词}")
print(dict(dictionary.iteritems()))

print ("##字典，{单词id，在多少文档中出现}")
print (dictionary.dfs) #字典，{单词id，在多少文档中出现}


# 训练集语料情况
print ("词袋，列表[(单词id，词频)]")
print(all_doc_list)
print(corpus) # 每一条语料中包含单词id及其在该语料中的词频
# Out:
# ##训练文档数目
# 8
# ##训练集字典，{单词id，对应的词}
# {0: '上海', 1: '不', 2: '喜欢', 3: '我', 4: '一个', 5: '地方', 6: '好', 7: '是', 8: '北京', 9: '哪里', 10: '在', 11: '好吃', 12: '的', 13: '好玩', 14: '人', 15: '和', 16: '路', 17: '小吃'}
# ##字典，{单词id，在多少文档中出现}
# {3: 1, 1: 1, 2: 2, 0: 6, 7: 3, 4: 2, 6: 3, 5: 3, 8: 1, 11: 1, 12: 2, 10: 2, 9: 2, 13: 1, 16: 1, 15: 1, 14: 1, 17: 1}
# 词袋，列表[(单词id，词频)]
# [['我', '不', '喜欢', '上海'], ['上海', '是', '一个', '好', '地方'], ['北京', '是', '一个', '好', '地方'], ['上海', '好吃', '的', '在', '哪里'], ['上海', '好玩', '的', '在', '哪里'], ['上海', '是', '好', '地方'], ['上海', '路', '和', '上海', '人'], ['喜欢', '小吃']]
# [[(0, 1), (1, 1), (2, 1), (3, 1)], [(0, 1), (4, 1), (5, 1), (6, 1), (7, 1)], [(4, 1), (5, 1), (6, 1), (7, 1), (8, 1)], [(0, 1), (9, 1), (10, 1), (11, 1), (12, 1)], [(0, 1), (9, 1), (10, 1), (12, 1), (13, 1)], [(0, 1), (5, 1), (6, 1), (7, 1)], [(0, 2), (14, 1), (15, 1), (16, 1)], [(2, 1), (17, 1)]]

# %%
doc1 = ['胸痛','胸闷','呼吸困难','恶心','冷','发汗','第三心音','第四心音','苍白','心电图_T波倒置','心电图_ST段压低','心电图_T波平坦','平板运动试验_ST段压低','平板运动试验_T波平坦','平板运动试验_T波倒置','核素心肌灌注试验_心肌缺血','负荷超声心动图_心肌缺血','年龄_≥40岁','性别_男性','性别_女性','年龄_＜40岁','个人史_绝经期','个人史_非绝经期','既往疾病_高血压','既往疾病_高脂血症','既往疾病_糖尿病','既往疾病（基本疾病）_高脂血症','既往疾病（基本疾病）_高血压','既往疾病（基本疾病）_糖尿病','疼痛部位','起病缓急','疼痛性质','持续时间','发作频率','发生过程','缓解方式','牵涉部位','发作频度','心前区','胸骨下段','胸骨后','剑突下','急性','慢性','压榨性','闷胀性','窒息性','烧灼感','小于15分钟','稳定','间歇性','持续性','一过性','突发','休息','硝酸甘油','颈部','肩臂部','下颌','肩部','左臂','右臂','上腹部','下腹部','背部','腰部','腹股沟','不稳定']
doc2 = ['疼痛部位','黄疸','呃逆','嗳气','腹胀','呕吐','恶心','胆绞痛','腹痛','墨菲氏(Murphy)征阳性','胆囊压痛','腹部压痛','腹部反跳痛','肌紧张','腹部超声 _胆囊结石','肝胆胰脾超声_胆囊结石','全腹部CT平扫 _胆囊结石','上腹部CT平扫 _胆囊结石','胆囊CT平扫 _胆囊结石','全腹部CT增强 _胆囊结石','上腹部CT增强 _胆囊结石','胆囊CT增强 _胆囊结石','全腹部核磁 _胆囊结石','上腹部核磁 _胆囊结石','胆囊核磁 _胆囊结石','全腹部核磁增强 _胆囊结石','上腹部核磁增强 _胆囊结石','胆囊核磁增强 _胆囊结石','年龄_≤40岁','年龄_＞40岁','性别_女性','性别_男性','右上腹','上腹部']
doc3 = ['胸痛','腹痛','咳嗽','恶心','吞咽困难','耳痛','声音嘶哑','烧心','反酸','胸骨后异物感','睡眠障碍','癔球症','上消化道造影_反流性食管炎','胃镜_反流性食管炎','PPI试验_阳性','多导腔内电阻抗_混合反流事件中位数≥26','多导腔内电阻抗_非酸返流事件中位数≥7','多导腔内电阻抗_液体反流事件中位数≥32','多导腔内电阻抗_气体反流事件中位数≥17','多导腔内电阻抗_酸返流事件中位数≥35','多导腔内电阻抗_弱酸返流事件中位数≥18','24小时食管pH监测_DeMesster积分＞14.72','疼痛性质','疼痛部位','胸骨后','刺痛','上腹部']
doc4 = ['相对浊音界扩大','收缩期喷射样杂音','第四心音','心脏平片_右心室增大','心脏平片_左心室扩大','心脏平片_左心房增大','心电图_T波倒置','心电图_病理性Q波','心电图_ST段压低','心导管造影_室间隔增厚','心导管造影_心室壁增厚','心导管造影_心腔缩小变形','心导管造影_左心室舒张压增高','核素心肌显像_显示心肌肥厚程度','核素心肌显像_显示心肌肥厚部位','核素心血管造影_室间隔增厚','核素心血管造影_左心室腔缩小','心脏超声_心肌肥厚']
doc5 = ['咯血','关节痛','面颊潮红','心悸','易激惹','月经不调','体重减轻','食欲减退','气促','乏力','倦怠','盗汗','畏寒','寒战','呼吸困难','胸痛','发热','咳痰','咳嗽','叩诊音浊音','呼吸音低','哮鸣音','气管移位','湿罗音（水泡音）','管状呼吸音','胸廓塌陷','纵隔移位','肺CT平扫_肺部感染','胸片_肺部感染','肺CT增强_肺部感染','肺核磁_肺部感染','肺核磁增强_肺部感染','痰培养_结核分歧杆菌阳性','抗结核抗体测定_阳性','结核菌素试验_强阳性','痰涂片_抗酸杆菌阴性','痰涂片_抗酸杆菌阳性','年龄_＞50岁','年龄_≤50岁','年龄_26—45岁','脉搏_大于120次/分','脉搏_≥125次/分','心率_≥125次/分','心率_≤100次/分','心率_＜60次/分','呼吸_≥30次','呼吸_≥25次','收缩压_大于90mmHg','收缩压_＜90mmHg','舒张压_≤60mmHg','尿量_小于20ml/h','尿量_小于80ml/4h','体温_≥40℃','体温_36.5—37.3℃','体温_＜35℃','地域_中国','既往疾病（基本疾病）_矽肺','既往疾病（基本疾病）_糖尿病','既往疾病（基本疾病）_肝炎','既往疾病（基本疾病）_艾滋病','性质','症状描述','血性','脓性','黏液性','咳嗽伴有痰液','刺激性咳嗽','干性咳嗽','哑铃型阴影','肺门淋巴结肿大','边缘模糊不清','斑片状阴影','肺纹理重','粟粒状结节阴影','好发于上叶下部和下叶上部','空洞','肺实变']
doc6 = ['疼痛部位','起病缓急','疼痛性质','持续时间','发作频率','发生过程','缓解方式','牵涉部位','发作频度','胸痛','胸闷','呼吸困难','恶心','冷','发汗','第三心音','第四心音','苍白','心电图_病理性Q波','心电图_2个以上导联ST段弓背向上抬高','心电图_新发的左束支传到阻滞','心脏超声_室壁运动异常','肌酸激酶同工酶测定_＞44U/L','肌钙蛋白T（TnT）测定_＞0.2u/L','肌钙蛋白I（TnI）测定_＞1.5ug/L','年龄_≥40岁','性别_男性','性别_女性','年龄_＜40岁','个人史_绝经期','个人史_非绝经期','既往疾病_高血压','既往疾病_高脂血症','既往疾病_糖尿病','既往疾病（基本疾病）_高脂血症','既往疾病（基本疾病）_高血压','既往疾病（基本疾病）_糖尿病','心前区','胸骨下段','胸骨后','剑突下','急性','慢性','压榨性','闷胀性','窒息性','烧灼感','小于15分钟','稳定','间歇性','持续性','一过性','突发','休息','硝酸甘油','颈部','肩臂部','下颌','肩部','左臂','右臂','上腹部','下腹部','背部','腰部','腹股沟','不稳定']
doc7 = ['畏寒','黄疸','发热','便秘','厌食','呕吐','恶心','腹胀','腹痛','墨菲氏(Murphy)征阳性','胆囊区叩击痛','腹部压痛','腹部反跳痛','腹部紧张度增强','腹部肿块','白细胞计数（WBC）_>9.5×109/L','总胆红素（T-Bil）测定_>17.1μmol/L','丙氨酸氨基转移酶（ALT）测定_>35U/L','淀粉酶（AMY）测定_>375U/L','牵涉部位','疼痛性质','背部','肩胛区','右肩','绞痛']
doc8 = ['胸痛','胸闷','呼吸困难','恶心','心电图_T波倒置','心电图_ST段压低','心电图_T波平坦','平板运动试验_ST段压低','平板运动试验_T波平坦','平板运动试验_T波倒置','核素心肌灌注试验_心肌缺血','负荷超声心动图_心肌缺血','年龄_≥40岁','性别_男性','性别_女性','年龄_＜40岁','个人史_绝经期','个人史_非绝经期','既往疾病_高血压','既往疾病_高脂血症','既往疾病_糖尿病','既往疾病（基本疾病）_高脂血症','既往疾病（基本疾病）_高血压','既往疾病（基本疾病）_糖尿病','牵涉部位','缓解方式','发生过程','发作频率','持续时间','疼痛性质','起病缓急','疼痛部位','发作频度','左臂','肩部','下颌','肩臂部','颈部','硝酸甘油','休息','突发','一过性','持续性','间歇性','不稳定','稳定','小于15分钟','烧灼感','窒息性','闷胀性','压榨性','慢性','急性','剑突下','胸骨后','胸骨下段','心前区','右臂','上腹部','下腹部','背部','腰部','腹股沟']
doc9 = ['乳房痛','乳房肿胀','发热','寒颤','上肢淋巴结肿大','乳头异常分泌物','乳房包块','乳房局限性压痛','乳房皮肤发红','乳房皮肤溃疡','乳房红肿','腋下浅表淋巴压痛','脉搏加快','白细胞计数（WBC）_>9.5×109/L','性质','胀痛']
doc10 = ['食欲缺乏','出汗','发热','心悸','发冷','吞咽困难','声音嘶哑','咳嗽','休克','水肿','腹痛','乏力','发绀','烦躁不安','面色发白','呼吸困难','胸痛','奇脉','异常支气管呼吸音','心动过速','心尖搏动弥散','肝大','舒张期额外心音','语音震颤增强','颈静脉怒张','心包摩擦音','心浊音界扩大','相对浊音区消失','心音轻快','心率快','肺浊音区','血压下降','静脉压上升','腹水','皮下水肿','肝颈静脉反流征','心电图_T波倒置','心脏超声_心包积液','心脏超声_心包压塞','心脏CT平扫_心包积液','心脏CT增强_心包积液','心脏核磁_心包积液','心脏核磁增强_心包积液','心脏平片_心包积液','心电图_心律失常','心电图_ST段抬高','心电图_T波高尖','心电图_T波低平','心电图_异常Q波','心电图_PR移位','心电图_QRS波低电压','心电图_电交替','放射性核素检查_心包积液','白细胞计数（WBC）_＞10x109/L','中性粒细胞计数_＞6.3x109/L','天门冬氨酸氨基转移酶（AST）测定_＞40U/L','天门冬氨酸氨基转移酶（AST）测定_＜40U/L','血沉方程K值_＞62.69','肌酸激酶（CK）测定_＞198.0U/L','肌酸激酶（CK）测定_18.0～198.0U/L','乳酸脱氢酶（LD）测定_＞215.0U/L','乳酸脱氢酶（LD）测定_135.0～215.0U/L','肌钙蛋白T（TnT）测定_＞0.2ug/L','肌钙蛋白I（TnI）测定_＞1.5ug/L','B型钠尿肽（BNP）测定_＞100pg/ml','C-反应蛋白（CRP）测定_＞8.2mg/L','疼痛性质','放射部位','疼痛部位','压迫样感','钝痛','剧痛','刀割样痛','右侧斜方肌','手','左前臂','咽部','上腹部','颈部','背部','肩部','心前区','胸骨后']
doc11 = ['腹痛','发热','恶心','呕吐','黄疸','腹胀','呼吸过速','腹部反跳痛','腹部紧张度增强','腹部压痛','肠鸣音减弱','Cullen征','Grey-Tuner征','胰腺CT平扫_胰腺炎','淀粉酶（AMY）测定_>300U/L','脂肪酶（LPS）测定_>200U/L','尿淀粉酶（AMY）测定_>1000U/L','程度','起病缓急','诱因或加重因素','疼痛部位','疼痛性质','剧烈','急性','进食油腻食物','酗酒','上腹部','束带感']
doc12 = ['气管移位','皮下气肿','颈静脉怒张','颈部肿胀','颈部压痛','纵隔浊音界扩大','Hamman征','胸部CT平扫_急性纵隔炎','胸部CT增强_急性纵隔炎','胸部核磁_急性纵隔炎','胸部核磁增强_急性纵隔炎','胸片_急性纵隔炎','既往疾病（基本疾病）_胰腺假性囊肿','既往疾病（基本疾病）_胰腺炎','既往疾病（基本疾病）_心包炎','既往疾病（基本疾病）_淋巴结炎','既往疾病（基本疾病）_胸膜炎','既往疾病（基本疾病）_肺部感染','既往疾病（基本疾病）_胸部贯穿伤','既往疾病（基本疾病）_感染炭疽杆菌','既往疾病（基本疾病）_支气管穿孔','既往疾病（基本疾病）_气管穿孔','既往疾病（基本疾病）_口底蜂窝织炎','既往疾病（基本疾病）_化脓性腮腺炎','既往疾病（基本疾病）_急性化脓性扁桃体炎','既往疾病（基本疾病）_食管穿孔','既往手术_胸骨切开术','纵隔结构层次不清','脂肪间隙模糊','液体聚集','纵隔增宽','层次不清','T1异常信号','T2异常信号','壁不规则增厚','脓肿壁强化','腔内脓液不强化','胸骨后密度增大','气管轮廓模糊','主动脉弓轮廓模糊','纵隔弧形阴影','食管移位','纵隔影增宽','纵隔气肿','颈部软组织气肿','肋膈角变钝','胸腔积液','症状描述']
doc13 = ['颈肩麻木','颈肩酸痛','肢体无力','肢体麻木','四肢活动不利','右手活动受限','手抖','尿频','排尿困难','头痛','头晕','呕吐','恶心','视力不佳','耳鸣','出汗','眼胀痛','心慌','心悸','听力下降','心动过缓','提睾反射','深反射','窦性心律不齐','耳聋','肛门反射','血压下降','臂丛牵拉试验阳性','压头试验阳性','腹壁反射','霍夫曼征阳性','髌阵挛阳性','踝阵挛阳性','巴彬斯基征阳性']
doc14 = ['咯血','焦虑','抑郁','食欲减退','体重下降','胸闷','喘息','呼吸困难','气促','咳嗽','咳痰','呼吸音低','发绀','叩诊音过清音','呼吸过缓','呼吸过速','干啰音','心尖搏动增强','桶状胸','结膜水肿','肝大','胸腹矛盾运动','下肢水肿','心浊音界缩小','肺肝界降低','呼气延长','湿啰音（水泡音）','心音遥远','胸片_慢性阻塞性肺疾病','白细胞计数（WBC）_＞10x10^9/L','红细胞计数（RBC）_女：＞5.5x10^12/L','红细胞计数（RBC）_男：＞6.0x10^12/L','红细胞比积测定（HCT）_＞50%','中性粒细胞计数_＞7x10^9/L','嗜酸性粒细胞计数_＞0.5x10^9/L','白蛋白（Alb）测定_＜35g/L','钾（K）测定_＜3.5mmol/L','钠（Na）测定_＜135mmol/L','氯（Cl）测定_＜96mmol/L','氧分压_＜60mmHg','氧分压_＜50mmHg','二氧化碳分压测定_＞70mmHg','二氧化碳分压测定_＞50mmHg','血液酸碱度检查_＜7.30','症状描述','肺过度充气','肺容积增大','胸腔前后径增长','肋骨走向变平','肺野透明度增高','横膈位置低平','心脏悬垂狭长','肺门血管纹理残根状','肺野外周血管纹理纤细稀少','肺大疱','右心增大','肺动脉圆锥彭隆','肺门血管影扩大','右下肺动脉增宽','类型','性质','发生部位','白色泡沫痰','脓性','黏液性','肺']
doc15 = ['咳痰','胸痛','发热','头痛','咳嗽','咯血','胸闷','呼吸困难','恶心','呕吐','腹泻','咽痛','皮疹','腹胀','寒战','肌肉痛','体重减轻','三凹征','呼吸过速','呼吸音低','叩诊音浊音','湿罗音（水泡音）','胸膜摩擦音','语音传导增强','语音震颤增强','斑丘疹','多形性红斑','水疱疹','潮红','急性病容','结节性红斑','冷','头颈部淋巴结肿大','神志谵妄','淡漠','鼻翼扇动','鼓膜充血','口唇颜色异常','Koplik斑','口咽部粘膜充血','哮鸣音','认知损害','空间定向异常','肺CT平扫_肺部感染','胸片_肺部感染','胰腺核磁_胰腺炎','白细胞计数（WBC）_＞10x109/L','白细胞计数（WBC）_＜4x109/L','葡萄糖（Glu）测定_≥14mmol/L','白蛋白（Alb）测定_＜35g/L','尿素（Urea）测定_＞7mmol/L','尿素（Urea）测定_≥7.14mmol/L','尿素（Urea）测定_≥11mmol/L','钠（Na）测定_＜130mmol/L','氧分压_＜70mmHg','氧分压_＜60mmHg','氧分压_＜54mmHg','血液酸碱度检查_＜7.35','血液酸碱度检查_＜7.30','氧饱和度_＜90%','降钙素原（PCT）检测_＜0.1ng/ml','血培养+鉴定+药敏_金黄色葡萄球菌甲氧西林敏感','血培养+鉴定+药敏_钾绿铜单杆菌','血培养+鉴定+药敏_不动杆菌属','血培养+鉴定+药敏_肺炎克雷伯菌','血培养+鉴定+药敏_肠杆菌科菌不产酶','血培养+鉴定+药敏_肠杆菌属细菌','血培养+鉴定+药敏_大肠埃希菌','血培养+鉴定+药敏_鲍曼不动杆菌','血培养+鉴定+药敏_多重耐药菌','血培养+鉴定+药敏_肺炎链球菌  青霉素MIC＜2mg/L','血培养+鉴定+药敏_肺炎链球菌  青霉素MIC＞2mg/L','血培养+鉴定+药敏_流感嗜血杆菌不产B内酰胺酶','血培养+鉴定+药敏_流感嗜血杆菌产B内酰胺酶','血培养+鉴定+药敏_卡他莫拉菌','血培养+鉴定+药敏_金黄色葡萄球菌甲氧西林耐药','血培养+鉴定+药敏_产ESBL肠科菌杆菌','血培养+鉴定+药敏_高产AmpC酶肠杆菌','血培养+鉴定+药敏_产碳青霉烯酶肠杆菌','血培养+鉴定+药敏_厌氧菌','血培养+鉴定+药敏_肺炎支原体','血培养+鉴定+药敏_肺炎衣原体','血培养+鉴定+药敏_军团菌','血培养+鉴定+药敏_鹦鹉热衣原体','血培养+鉴定+药敏_伯士考克斯体','血培养+鉴定+药敏_类鼻疽博克霍尔德菌','血培养+鉴定+药敏_百日咳博德特菌','血培养+鉴定+药敏_嗜麦芽窄食单胞菌','血培养+鉴定+药敏_奴卡菌','血培养+鉴定+药敏_放射菌','血培养+鉴定+药敏_鼠疫耶尔森菌','血培养+鉴定+药敏_肺炭疽','血培养+鉴定+药敏_曲霉','血培养+鉴定+药敏_毛霉','血培养+鉴定+药敏_肺孢子肺炎','血培养+鉴定+药敏_有荚膜包绕的酵母菌','血培养+鉴定+药敏_荚膜组织胞浆菌','血培养+鉴定+药敏_马尔尼菲青霉菌','血培养+鉴定+药敏_呼吸道合胞病毒','红细胞比积测定（HCT）_＜30%','年龄_≥65岁','年龄_≥80岁','年龄_＞50岁','年龄_≤50岁','年龄_26—45岁','体温_≥40度','体温_36.5—37.3','体温_＜35','脉搏_大于120次/分','脉搏_≥125次/分','心率_≥125次/分','心率_≤100次/分','心率_＜60次/分','呼吸_≥30次','呼吸_≥25次','收缩压_大于90mmHg','收缩压_＜90mmHg','舒张压_≤60mmHg','尿量_小于20ml/h','尿量_小于80ml/4h','地域_中国','既往疾病_脑卒中','既往疾病_慢性肾功能不全','既往疾病_糖尿病','既往疾病_慢性呼吸系统疾病','既往疾病_慢性阻塞性肺疾病','既往疾病_慢性支气管炎','既往疾病_支气管扩张','既往疾病_慢性心力衰竭','既往疾病_充血性心力衰竭','既往疾病_肝脏疾病','既往疾病_免疫抑制','既往疾病_酗酒','既往疾病_哮喘','性质','类型','放射部位','疼痛性质','发生部位','部位','症状描述','脓性','血性','恶臭痰','铁锈色痰','黄绿色痰','暗红色胶冻样痰','褐色痰','腰部','背部','刺痛','肺','皮肤','全身','颈部','颅脑','鼻','耳','口腔','炎性实变大于1个肺叶','胸腔积液','间质性改变','磨玻璃影','斑片状浸润','实变影','树芽征','多肺叶浸润']
doc16 = ['发绀','咳嗽','心悸','气促','腹胀','上腹不适','嗳气','贫血','吞咽困难','反流','烧心','上消化道造影_食管裂孔疝','胃镜_食管裂孔疝','性质','位置','症状描述','疼痛','烧灼感','剑突下','胸骨后','食管下段齿状线上移','食管腔内有潴留液','贲门口扩大和松弛','His角变钝','胃底变浅','膈食管裂孔宽大而松弛']
doc17 = ['胸痛','胸闷','呼吸困难','恶心','呕吐','苍白','发汗','冷','第三心音','第四心音','心电图_T波倒置','心电图_ST段压低','心电图_T波平坦','平板运动试验_ST段压低','平板运动试验_T波平坦','平板运动试验_T波倒置','核素心肌灌注试验_心肌缺血','负荷超声心动图_心肌缺血','冠脉CTA_狭窄≤50%','冠脉CTA_狭窄＞50%','冠脉造影_狭窄≤50%','冠脉造影_狭窄＞50%','年龄_≥40岁','年龄_<40岁','性别_男性','性别_女性','既往疾病_糖尿病','个人史_绝经期','个人史_非绝经期','既往疾病_高血压','既往疾病_高脂血症','疼痛部位','放射部位','起病缓急','疼痛性质','持续时间','缓解方式','发生过程','发作频率','胸骨后','剑突下','心前区','肩部','颈部','上腹部','下腹部','腰部','腹股沟','背部','急性','慢性','灼烧痛','压榨样痛','窒息感','小于15分钟','闷胀性','右臂','胸骨下段','肩臂部','下颌','左臂','硝酸甘油','休息','间歇性','持续性','一过性','突发','稳定']
doc18 = ['发热','咳嗽','咳痰','胸痛','气促','胸闷','食欲不振','乏力','消瘦','盗汗','叩诊音实音','叩诊音浊音','呼吸运动减弱','异常呼吸音','气管移位','水肿','肋间隙变窄','胸壁压痛','胸廓不对称','胸膜摩擦音','心脏移位','杵状指（趾）','胸水比重测定_>1.018','胸水蛋白定量测定_>30g/L','胸水多核细胞测定_100-1000m3','胸水葡萄糖（GLU）检测_>60mg/dl','胸水腺苷脱氨酶（ADA）检测_>70IU/L','胸水PH值测定_7.30-7.40','γ干扰素(IFN-γ)_>5.51μg/L','分度','性质','痰量','疼痛部位','疼痛性质','低热（37.3-38）','高热（39.1-41）','干性咳嗽','脓性','血性','多','腋下','刺痛']
doc19 = ['呼吸困难','烦躁不安','意识障碍','出汗','发绀','叩诊音鼓音','呼吸过速','异常肺泡呼吸音','气管移位','皮下气肿','颈静脉怒张','脉搏加快']
doc20 = ['食欲不振','盗汗','胸痛','发热','咯血','咳痰','咳嗽','哮鸣音','干啰音','湿罗音（水泡音）','杵状指','胸片_支气管扩张','高分辨率CT_支气管扩张','频率','痰量','类型','性质','起病时间','起病缓急','症状描述','反复','多','黄绿色痰','脓性','晨起咳嗽','夜间咳嗽','慢性','肺纹理增多','轨道征','卷发征','类环形阴影','柱状改变','囊状改变','气道壁增厚','黏液阻塞','树枝发芽征','马赛克征','双轨征','串珠状改变','印城征','蜂窝状改变','杆状改变']
doc21 = ['眼痒','喷嚏','鼻塞','气促','胸闷','喘息','呼吸困难','咳嗽','三凹征','发绀','呼吸运动减弱','哮鸣音','嗜睡','奇脉','意识模糊','气短','湿罗音（水泡音）','焦虑','语音震颤减弱','心率加快','静止肺','呼气音延长','致病因素_运动','致病因素_病毒性上呼吸道感染','致病因素_物理、化学性刺激','致病因素_冷空气','致病因素_接触变应原','时间点','频率','发作时间','起病时间','晨起','夜间','反复发作','晨起咳嗽','夜间咳嗽']
doc22 = ['栓塞','咯血','出汗','活动耐力显著下降','乏力','晕厥','胸痛','呼吸困难','心悸','Duroziez双重杂音','心尖搏动移位','收缩期吹风样杂音','枪击音','毛细血管搏动征','水冲脉','水肿','第二心音异常','肝大','舒张期额外心音','心界扩大','颈动脉搏动增强','脉压增大','点头征','收缩前期额外心音','异常心音','颈静脉怒张','心脏超声_主动脉瓣关闭不全','心电图_左心室肥厚劳损','心电图_电轴左偏','心电图_心室传导阻滞','心电图_心律失常','心脏平片_主动脉瓣关闭不全','既往疾病（基本疾病）_梅毒性主动脉炎','既往疾病（基本疾病）_马方综合征','既往疾病（基本疾病）_感染性心内膜炎','既往疾病（基本疾病）_风湿性心脏病','症状描述','左心室增大','升主动脉结扩张','高调递减型哈气样杂音','柔和低调的隆隆样杂音（Austin-Flint杂音）']
doc23 = ['发绀','心动过速','咳嗽','吞咽困难','牙关紧闭','呼吸困难','心搏加快','胸痛','烦躁不安','气促','伤口渗出','伤口红肿','心悸','寒战','发热','分度','高热（39.1-41）']

# %%
# 分词
all_doc_list = []

all_doc_list.append(doc1)
all_doc_list.append(doc2)
all_doc_list.append(doc3)
all_doc_list.append(doc4)
all_doc_list.append(doc5)
all_doc_list.append(doc6)
all_doc_list.append(doc7)
all_doc_list.append(doc8)
all_doc_list.append(doc9)
all_doc_list.append(doc10)
all_doc_list.append(doc11)
all_doc_list.append(doc12)
all_doc_list.append(doc13)
all_doc_list.append(doc14)
all_doc_list.append(doc15)
all_doc_list.append(doc16)
all_doc_list.append(doc17)
all_doc_list.append(doc18)
all_doc_list.append(doc19)
all_doc_list.append(doc20)
all_doc_list.append(doc21)
all_doc_list.append(doc22)
all_doc_list.append(doc23)

# %%
print(all_doc_list[0])
# Out:
# ['胸痛', '胸闷', '呼吸困难', '恶心', '冷', '发汗', '第三心音', '第四心音', '苍白', '心电图_T波倒置', '心电图_ST段压低', '心电图_T波平坦', '平板运动试验_ST段压低', '平板运动试验_T波平坦', '平板运动试验_T波倒置', '核素心肌灌注试验_心肌缺血', '负荷超声心动图_心肌缺血', '年龄_≥40岁', '性别_男性', '性别_女性', '年龄_＜40岁', '个人史_绝经期', '个人史_非绝经期', '既往疾病_高血压', '既往疾病_高脂血症', '既往疾病_糖尿病', '既往疾病（基本疾病）_高脂血症', '既往疾病（基本疾病）_高血压', '既往疾病（基本疾病）_糖尿病', '疼痛部位', '起病缓急', '疼痛性质', '持续时间', '发作频率', '发生过程', '缓解方式', '牵涉部位', '发作频度', '心前区', '胸骨下段', '胸骨后', '剑突下', '急性', '慢性', '压榨性', '闷胀性', '窒息性', '烧灼感', '小于15分钟', '稳定', '间歇性', '持续性', '一过性', '突发', '休息', '硝酸甘油', '颈部', '肩臂部', '下颌', '肩部', '左臂', '右臂', '上腹部', '下腹部', '背部', '腰部', '腹股沟', '不稳定']

# %%
# 简单样例1
import jieba
from gensim import corpora,models,similarities
import warnings
warnings.filterwarnings(action='ignore',category=UserWarning,module='gensim')

# 获取词袋
dictionary = corpora.Dictionary(all_doc_list) 


# 制作语料库
doc_train_vec = [dictionary.doc2bow(doc) for doc in all_doc_list]
corpus = [dictionary.doc2bow(doc) for doc in all_doc_list]
# Out:
# D:\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
dictionary.num_pos
# Out:
# 1105

# %%
# 测试
doc_test_list = ['胸痛','胸闷','呼吸困难','关节痛','面颊潮红','发热','头痛','咳嗽','咯血']
doc_test_vec = dictionary.doc2bow(doc_test_list)



# tf-idf
tfidf = models.TfidfModel(doc_train_vec)


index = similarities.SparseMatrixSimilarity(tfidf[doc_train_vec], num_features=len(dictionary.keys()))

sim = index[tfidf[doc_test_vec]]

sorted(enumerate(sim), key=lambda item: -item[1])
# Out:
# [(4, 0.1919654),
#  (12, 0.061932143),
#  (14, 0.05835583),
#  (22, 0.049343772),
#  (19, 0.04684271),
#  (13, 0.036213137),
#  (17, 0.03478263),
#  (21, 0.031586356),
#  (7, 0.02622115),
#  (0, 0.024950407),
#  (20, 0.024561862),
#  (5, 0.023196675),
#  (16, 0.022439804),
#  (9, 0.01765727),
#  (2, 0.015052714),
#  (8, 0.013643764),
#  (6, 0.012902586),
#  (10, 0.01224462),
#  (15, 0.009746625),
#  (18, 0.009733875),
#  (1, 0.0),
#  (3, 0.0),
#  (11, 0.0)]

# %%
print(dict(dictionary.iteritems()))
# Out:
# {0: '一过性', 1: '上腹部', 2: '下腹部', 3: '下颌', 4: '不稳定', 5: '个人史_绝经期', 6: '个人史_非绝经期', 7: '休息', 8: '冷', 9: '剑突下', 10: '压榨性', 11: '发作频度', 12: '发作频率', 13: '发汗', 14: '发生过程', 15: '右臂', 16: '呼吸困难', 17: '小于15分钟', 18: '左臂', 19: '平板运动试验_ST段压低', 20: '平板运动试验_T波倒置', 21: '平板运动试验_T波平坦', 22: '年龄_≥40岁', 23: '年龄_＜40岁', 24: '心前区', 25: '心电图_ST段压低', 26: '心电图_T波倒置', 27: '心电图_T波平坦', 28: '急性', 29: '性别_女性', 30: '性别_男性', 31: '恶心', 32: '慢性', 33: '持续性', 34: '持续时间', 35: '既往疾病_糖尿病', 36: '既往疾病_高脂血症', 37: '既往疾病_高血压', 38: '既往疾病（基本疾病）_糖尿病', 39: '既往疾病（基本疾病）_高脂血症', 40: '既往疾病（基本疾病）_高血压', 41: '核素心肌灌注试验_心肌缺血', 42: '烧灼感', 43: '牵涉部位', 44: '疼痛性质', 45: '疼痛部位', 46: '硝酸甘油', 47: '稳定', 48: '突发', 49: '窒息性', 50: '第三心音', 51: '第四心音', 52: '缓解方式', 53: '肩臂部', 54: '肩部', 55: '背部', 56: '胸痛', 57: '胸闷', 58: '胸骨下段', 59: '胸骨后', 60: '腰部', 61: '腹股沟', 62: '苍白', 63: '负荷超声心动图_心肌缺血', 64: '起病缓急', 65: '间歇性', 66: '闷胀性', 67: '颈部', 68: '上腹部CT增强 _胆囊结石', 69: '上腹部CT平扫 _胆囊结石', 70: '上腹部核磁 _胆囊结石', 71: '上腹部核磁增强 _胆囊结石', 72: '全腹部CT增强 _胆囊结石', 73: '全腹部CT平扫 _胆囊结石', 74: '全
# ...

# %%
tfidf

# %%
tfidf[1,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-059826bd1ecb> in <module>()
# ----> 1 tfidf[1,1]
#
# D:\Anaconda3\lib\site-packages\gensim\models\tfidfmodel.py in __getitem__(self, bow, eps)
#     424
#     425         termid_array, tf_array = [], []
# --> 426         for termid, tf in bow:
#     427             termid_array.append(termid)
#     428             tf_array.append(tf)
#
# TypeError: 'int' object is not iterable
